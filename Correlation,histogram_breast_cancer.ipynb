# %% [markdown]
# <a href="https://colab.research.google.com/github/HARINIDEVI23/Breast-cancer-tumor-Prediction/blob/main/Correlation%2Chistogram_breast_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
df <- read.csv("/content/bmd.csv")

# %%
str(df)
# Out:
# 'data.frame':	169 obs. of  9 variables:
#  $ id          : int  469 8724 6736 24180 17072 3806 17106 23834 2454 2088 ...
#  $ age         : num  57.1 75.7 70.8 78.2 54.2 ...
#  $ sex         : chr  "F" "F" "M" "F" ...
#  $ fracture    : chr  "no fracture" "no fracture" "no fracture" "no fracture" ...
#  $ weight_kg   : num  64 78 73 60 55 65 77 59 64 72 ...
#  $ height_cm   : num  156 162 170 148 161 ...
#  $ medication  : chr  "Anticonvulsant" "No medication" "No medication" "No medication" ...
#  $ waiting_time: int  18 56 10 14 20 7 26 9 6 10 ...
#  $ bmd         : num  0.879 0.795 0.907 0.711 0.791 ...

# %%
summary(df)
# Out:
#        id             age            sex              fracture
#  Min.   :   35   Min.   :35.81   Length:169         Length:169
#  1st Qu.: 2018   1st Qu.:54.42   Class :character   Class :character
#  Median : 6702   Median :63.49   Mode  :character   Mode  :character
#  Mean   : 9103   Mean   :63.63
#  3rd Qu.:17100   3rd Qu.:72.08
#  Max.   :24208   Max.   :88.75
#    weight_kg       height_cm      medication         waiting_time
#  Min.   :36.00   Min.   :142.0   Length:169         Min.   : 5.00
#  1st Qu.:56.00   1st Qu.:154.0   Class :character   1st Qu.: 9.00
#  Median :64.50   Median :160.5   Mode  :character   Median :14.00
#  Mean   :64.67   Mean   :160.3                      Mean   :19.74
#  3rd Qu.:73.00   3rd Qu.:166.0                      3rd Qu.:24.00
#  Max.   :96.00   Max.   :177.0                      Max.   :96.00
#       bmd
#  Min.   :0.4076
#  1st Qu.:0.6708
#  Median :0.7861
#  Mean   :0.7831
#  3rd Qu.:0.8888
#  Max.   :1.3624

# %%
sum(is.na(df))
# Out:
# [1] 569

# %%
sum(duplicated(df))
# Out:
# [1] 0

# %%
# Drop unnecessary columns
data <- data %>%
  select(-id)  # Assuming 'id' column is unnecessary

# Save the updated dataset as a CSV file
write.csv(data, file = "datascienceup.csv", row.names = FALSE)

# %%
unique(data$diagnosis)
# Out:
# [1] "M" "B"

# %%
data$diagnosis <- as.factor(data$diagnosis)

# %%
summary(df)
# Out:
#        id             diagnosis          radius_mean      texture_mean
#  Min.   :     8670   Length:569         Min.   : 6.981   Min.   : 9.71
#  1st Qu.:   869218   Class :character   1st Qu.:11.700   1st Qu.:16.17
#  Median :   906024   Mode  :character   Median :13.370   Median :18.84
#  Mean   : 30371831                      Mean   :14.127   Mean   :19.29
#  3rd Qu.:  8813129                      3rd Qu.:15.780   3rd Qu.:21.80
#  Max.   :911320502                      Max.   :28.110   Max.   :39.28
#  perimeter_mean     area_mean      smoothness_mean   compactness_mean
#  Min.   : 43.79   Min.   : 143.5   Min.   :0.05263   Min.   :0.01938
#  1st Qu.: 75.17   1st Qu.: 420.3   1st Qu.:0.08637   1st Qu.:0.06492
#  Median : 86.24   Median : 551.1   Median :0.09587   Median :0.09263
#  Mean   : 91.97   Mean   : 654.9   Mean   :0.09636   Mean   :0.10434
#  3rd Qu.:104.10   3rd Qu.: 782.7   3rd Qu.:0.10530   3rd Qu.:0.13040
# ...

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Load necessary library
library(ggplot2)

# Assuming your dataframe is named 'df'

# %%
summary(df)
# Out:
#        id             diagnosis          radius_mean      texture_mean
#  Min.   :     8670   Length:569         Min.   : 6.981   Min.   : 9.71
#  1st Qu.:   869218   Class :character   1st Qu.:11.700   1st Qu.:16.17
#  Median :   906024   Mode  :character   Median :13.370   Median :18.84
#  Mean   : 30371831                      Mean   :14.127   Mean   :19.29
#  3rd Qu.:  8813129                      3rd Qu.:15.780   3rd Qu.:21.80
#  Max.   :911320502                      Max.   :28.110   Max.   :39.28
#  perimeter_mean     area_mean      smoothness_mean   compactness_mean
#  Min.   : 43.79   Min.   : 143.5   Min.   :0.05263   Min.   :0.01938
#  1st Qu.: 75.17   1st Qu.: 420.3   1st Qu.:0.08637   1st Qu.:0.06492
#  Median : 86.24   Median : 551.1   Median :0.09587   Median :0.09263
#  Mean   : 91.97   Mean   : 654.9   Mean   :0.09636   Mean   :0.10434
#  3rd Qu.:104.10   3rd Qu.: 782.7   3rd Qu.:0.10530   3rd Qu.:0.13040
# ...

# %%
ggplot(data = df, aes(x = diagnosis, y = radius_mean, fill = diagnosis)) +
  geom_boxplot() +
  labs(title = "Boxplot of Radius Mean by Diagnosis",
       x = "Diagnosis",
       y = "Radius Mean") +
  theme_minimal()
# Out:
# plot without title

# %%
df$smoothness_mean <- as.factor(df$smoothness_mean)

# Creating a boxplot with ggplot2
ggplot(data = df, aes(x = smoothness_mean, y = compactness_mean, group = smoothness_mean)) +
  geom_boxplot() +
  labs(title = "Boxplot For Breast Cancer",
       x = "Smoothness Mean",
       y = "Compactness Mean") +
  theme_minimal()
# Out:
# plot without title

# %%
ggplot(data, aes(x = as.factor(smoothness_worst), y = compactness_worst, fill = as.factor(concavity_worst))) +
  geom_boxplot() +
  labs(title = "Box Plot of Compactness Worst by Smoothness Worst and Concavity Worst") +
  theme_minimal()
# Out:
# plot without title

# %%
library(dplyr)

# Define the range for fractal_dimension_se
min_value <- 0.003  # Define your minimum value
max_value <- 0.006  # Define your maximum value

# Filter the data for the specified range of values
filtered_data <- data %>%
  filter(fractal_dimension_se >= min_value & fractal_dimension_se <= max_value)

# Create the box plot for the filtered data
ggplot(filtered_data, aes(x = as.factor(fractal_dimension_se), y = radius_worst, fill = as.factor(texture_worst))) +
  geom_boxplot() +
  labs(title = "Box Plot of Radius Worst by Fractal Dimension Se and Texture Worst (Filtered)") +
  theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = smoothness_worst, y = compactness_worst, fill = diagnosis)) +
  geom_boxplot() +
  labs(title = "Boxplot of Compactness Worst by Smoothness Worst and Diagnosis",
       x = "Smoothness Worst",
       y = "Compactness Worst") +
  theme_minimal()
# Out:
# plot without title

# %%
# Assuming df contains your data
# Load necessary libraries
library(ggplot2)

# Create a histogram
ggplot(data = df, aes(x = smoothness_worst, fill = diagnosis)) +
  geom_histogram(binwidth = 0.1, color = "black", alpha = 0.5) +
  labs(title = "Histogram of Smoothness Worst by Diagnosis",
       x = "Smoothness Worst",
       y = "Frequency") +
  theme_minimal()
# Out:
# plot without title

# %%
# Assuming df contains your data
# Load necessary libraries
library(ggplot2)

# Create a bar plot
ggplot(data = df, aes(x = diagnosis, fill = diagnosis)) +
  geom_bar() +
  labs(title = "Bar Plot of Diagnosis",
       x = "Diagnosis",
       y = "Count") +
  theme_minimal()
# Out:
# plot without title

# %%
# Assuming df contains your data
# Load necessary libraries
library(ggplot2)

# Create a histogram for a single attribute
ggplot(data = df, aes(x = smoothness_worst)) +
  geom_histogram(binwidth = 0.1, color = "black", fill = "skyblue", alpha = 0.7) +
  labs(title = "Histogram of Smoothness Worst",
       x = "Smoothness Worst",
       y = "Frequency") +
  theme_minimal()
# Out:
# plot without title

# %%
ggplot(data = df, aes(x = texture_worst, y = radius_worst, fill = diagnosis)) +
  geom_boxplot() +
  labs(title = "Boxplot of Radius Worst by Texture Worst and Diagnosis",
       x = "Texture Worst",
       y = "Radius Worst") +
  theme_minimal()
# Out:
# plot without title

# %%
# Assuming df contains your data
# Load necessary libraries
library(pROC)
library(ggplot2)

# Create the boxplot
ggplot(data = df, aes(x = texture_worst, y = radius_worst, fill = diagnosis)) +
  geom_boxplot() +
  labs(title = "Boxplot of Radius Worst by Texture Worst and Diagnosis",
       x = "Texture Worst",
       y = "Radius Worst") +
  theme_minimal()

# Perform linear regression
lm_model <- lm(radius_worst ~ texture_worst, data = df)

# Make predictions
predictions <- predict(lm_model, newdata = df)

# Calculate lift curve
roc_curve <- roc(df$diagnosis, predictions)
lift <- lift_curve(roc_curve)
lift_df <- data.frame(1:length(lift$percent_of_positives), lift$percent_of_positives, lift$lift)

# Plot lift curve
ggplot(lift_df, aes(x = X1.length.lift.percent_of_positives., y = lift)) +
  geom_line() +
  geom_hline(yintercept = 1, linetype = "dashed", color = "red") +
  labs(x = "Number of Instances", y = "Lift", title = "Lift Curve")
# Out:
# Setting levels: control = B, case = M
#
# Setting direction: controls < cases
# Error in lift_curve(roc_curve): could not find function "lift_curve"
# Traceback:
# plot without title

# %%
# Remove rows with missing values
df <- na.omit(df)

# Perform linear regression
lm_model <- lm(diagnosis ~ smoothness_worst, data = df)

# Make predictions
predictions <- predict(lm_model, newdata = df)

# Calculate lift curve
roc_curve <- roc(df$diagnosis, predictions)
lift <- lift_curve(roc_curve)
lift_df <- data.frame(1:length(lift$percent_of_positives), lift$percent_of_positives, lift$lift)

# Plot lift curve
ggplot(lift_df, aes(x = X1.length.lift.percent_of_positives., y = lift)) +
  geom_line() +
  geom_hline(yintercept = 1, linetype = "dashed", color = "red") +
  labs(x = "Number of Instances", y = "Lift", title = "Lift Curve")
# Out:
# Warning message in storage.mode(v) <- "double":
# “NAs introduced by coercion”
# Error in lm.fit(x, y, offset = offset, singular.ok = singular.ok, ...): NA/NaN/Inf in 'y'
# Traceback:
#
# 1. lm(diagnosis ~ smoothness_worst, data = df)
# 2. lm.fit(x, y, offset = offset, singular.ok = singular.ok, ...)

# %%
# Assuming df contains your data
# Load necessary libraries
library(ggplot2)
library(pROC)

# Create a histogram for a single attribute
ggplot(data = df, aes(x = smoothness_worst)) +
  geom_histogram(binwidth = 0.1, color = "black", fill = "skyblue", alpha = 0.7) +
  labs(title = "Histogram of Smoothness Worst",
       x = "Smoothness Worst",
       y = "Frequency") +
  theme_minimal()

# Perform linear regression
lm_model <- lm(diagnosis ~ smoothness_worst, data = df)

# Make predictions
predictions <- predict(lm_model, newdata = df)

# Calculate lift curve
roc_curve <- roc(df$diagnosis, predictions)
lift <- lift_curve(roc_curve)
lift_df <- data.frame(1:length(lift$percent_of_positives), lift$percent_of_positives, lift$lift)

# Plot lift curve
ggplot(lift_df, aes(x = X1.length.lift.percent_of_positives., y = lift)) +
  geom_line() +
  geom_hline(yintercept = 1, linetype = "dashed", color = "red") +
  labs(x = "Number of Instances", y = "Lift", title = "Lift Curve")
# Out:
# Warning message in storage.mode(v) <- "double":
# “NAs introduced by coercion”
# Error in lm.fit(x, y, offset = offset, singular.ok = singular.ok, ...): NA/NaN/Inf in 'y'
# Traceback:
#
# 1. lm(diagnosis ~ smoothness_worst, data = df)
# 2. lm.fit(x, y, offset = offset, singular.ok = singular.ok, ...)
# plot without title

# %%
library(readr)
data <- read.csv('datascience.csv')
numeric_data <- data[, sapply(data, is.numeric)]
print(head(numeric_data))
correlation_matrix <- cor(numeric_data)
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
#         id radius_mean texture_mean perimeter_mean area_mean smoothness_mean
# 1   842302       17.99        10.38         122.80    1001.0         0.11840
# 2   842517       20.57        17.77         132.90    1326.0         0.08474
# 3 84300903       19.69        21.25         130.00    1203.0         0.10960
# 4 84348301       11.42        20.38          77.58     386.1         0.14250
# 5 84358402       20.29        14.34         135.10    1297.0         0.10030
# 6   843786       12.45        15.70          82.57     477.1         0.12780
#   compactness_mean concavity_mean concave.points_mean symmetry_mean
# 1          0.27760         0.3001             0.14710        0.2419
# 2          0.07864         0.0869             0.07017        0.1812
# 3          0.15990         0.1974             0.12790        0.2069
# 4          0.28390         0.2414             0.10520        0.2597
# 5          0.13280         0.1980             0.10430        0.1809
# ...

# %%
library(readr)
data <- read.csv('datascience.csv')
numeric_data <- data[, sapply(data, is.numeric)]
correlation_matrix <- cor(numeric_data)
heatmap(correlation_matrix,
        col = colorRampPalette(c("blue", "white", "red"))(100),
        main = "Correlation Heatmap",

)
# Out:
# Plot with title “Correlation Heatmap”

# %%
library(readr)
library(dplyr)
data <- read.csv('datascience.csv')
numeric_data <- data[, sapply(data, is.numeric)]
anova_results <- sapply(numeric_data, function(x) {
  if(length(unique(data$diagnosis)) == 2) {
    t_test_result <- t.test(x ~ data$diagnosis)
    p_value <- t_test_result$p.value
  } else {
    anova_result <- aov(x ~ data$diagnosis)
    p_value <- summary(anova_result)[[1]][["Pr(>F)"]][[1]]
  }
  return(p_value)
})
selected_features <- names(sort(anova_results, decreasing = FALSE)[1:10])
print(selected_features)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#  [1] "concave.points_worst" "perimeter_worst"      "concave.points_mean"
#  [4] "radius_worst"         "perimeter_mean"       "radius_mean"
#  [7] "concavity_worst"      "concavity_mean"       "area_worst"
# [10] "area_mean"

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Load the required library
library(tidyverse)

# Load the dataset
data <- read.csv("datascience.csv")

# Explore the dataset
head(data)
summary(data)

# Split the data into training and testing sets
set.seed(123)
train_indices <- sample(nrow(data), 0.7 * nrow(data))
train_data <- data[train_indices, ]
test_data <- data[-train_indices, ]

# Fit a linear regression model
model <- lm(target_variable ~ ., data = train_data)

# Make predictions on the test set
predictions <- predict(model, newdata = test_data)

# Evaluate the model
rmse <- sqrt(mean((predictions - test_data$target_variable)^2))
rmse
